# %%
'''
Base Model full pipeline
'''
# Out:
# '\nBase Model full pipeline\n'

# %%
from __future__ import absolute_import, division, print_function

# %%
import tensorflow as tf

tf.enable_eager_execution()
tf.__version__
# Out:
# '1.13.1'

# %%
from tensorflow.keras.layers import Bidirectional,CuDNNGRU,CuDNNLSTM,GRU,LSTM,concatenate,Dense,Input,Embedding
from tensorflow.keras.layers import  multiply, Flatten
from tensorflow.keras.layers import Lambda, Masking
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from hyperopt import Trials, STATUS_OK, tpe,  fmin, tpe, hp, STATUS_OK, Trials
import importlib
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
# !pip install h5py

# !apt-get install -y libhdf5-dev

# !pip install fasttext
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.11.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libhdf5-dev is already the newest version (1.10.0-patch1+docs-4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
# Collecting fasttext
#   Downloading https://files.pythonhosted.org/packages/a4/86/ff826211bc9e28d4c371668b30b4b2c38a09127e5e73017b1c0cd52f9dfa/fasttext-0.8.3.tar.gz (73kB)
#     100% |████████████████████████████████| 81kB 3.2MB/s
# Requirement already satisfied: numpy>=1 in /usr/local/lib/python3.6/dist-packages (from fasttext) (1.14.6)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from fasttext) (0.16.0)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/73/8e/5d/ecb50b90adaab5868ae1d8df180f31e55e85c2f055aaf2fb35
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.8.3

# %%
import json
import fasttext
import numpy as np
import pandas as pd
import tensorflow_hub as hub
import tensorflow.keras.layers as layers
from tensorflow.keras.datasets import imdb
from gensim.models import Word2Vec
from gensim.models import FastText
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import accuracy_score,classification_report
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0326 15:00:04.625169 139987048392576 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14

# %%
import h5py

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Scikit-learn includes many helpful utilities
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

import re
import numpy as np
import os
import time
import json
from glob import glob
from PIL import Image
import pickle

# %% [markdown]
# ## Download and prepare the MS-COCO dataset

# %%
annotation_zip = tf.keras.utils.get_file('captions.zip', 
                                          cache_subdir=os.path.abspath('.'),
                                          origin = 'http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                          extract = True)
annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'

name_of_zip = 'train2014.zip'
if not os.path.exists(os.path.abspath('.') + '/' + name_of_zip):
  image_zip = tf.keras.utils.get_file(name_of_zip, 
                                      cache_subdir=os.path.abspath('.'),
                                      origin = 'http://images.cocodataset.org/zips/train2014.zip',
                                      extract = True)
  PATH = os.path.dirname(image_zip)+'/train2014/'
else:
  PATH = os.path.abspath('.')+'/train2014/'
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 3s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 219s 0us/step

# %% [markdown]
# **Utility functions**
#
# ---
#
# ---
#
# # Prepare the Embeddings using word vector models

# %%
params_set = {
    "embed_dim":300,
    "split_ratio":0.33,
    "max_len":200,
    "vocab_size":10000,
    "trainable_param":"False",
    "option":2,
    "workers":3,
    "window":1

}

model_params = {
    "epochs":10,
    "batch_size":1024,
    "loss":"binary_crossentropy",
    "optimizer":"adam",
    "metrics":["accuracy"]

}


def json_to_dict(json_set):
    for k,v in json_set.items():
        if v == "True":
            json_set[k]= True
        elif v == "False":
            json_set[k]=False
        else:
            json_set[k]=v
    return json_set

  
  


def load_data(vocab_size,max_len):
    """
        Loads the keras imdb dataset
        Args:
            vocab_size = {int} the size of the vocabulary
            max_len = {int} the maximum length of input considered for padding
        Returns:
            X_train = tokenized train data
            X_test = tokenized test data
    """
    INDEX_FROM = 3

    (X_train,y_train),(X_test,y_test) = imdb.load_data(num_words = vocab_size,index_from = INDEX_FROM)

    return X_train,X_test,y_train,y_test


def prepare_data_for_word_vectors_imdb(X_train):
    """
        Prepares the input
        Args:
            X_train = tokenized train data
        Returns:
            sentences = {list} sentences containing words as tokens
            word_index = {dict} word and its indexes in whole of imdb corpus
    """
    INDEX_FROM = 3
    word_to_index = imdb.get_word_index()
    word_to_index = {k:(v+INDEX_FROM) for k,v in word_to_index.items()}

    word_to_index["<START>"] =1
    word_to_index["<UNK>"]=2

    index_to_word = {v:k for k,v in word_to_index.items()}

    sentences = []
    for i in range(len(X_train)):
        temp = [index_to_word[ids] for ids in X_train[i]]
        sentences.append(temp)
    """
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(sentences)
    word_indexes = tokenizer.word_index
    """
    return sentences,word_to_index


def prepare_data_for_word_vectors(X):
    sentences_as_words=[]
    word_to_index={}
    count=1
    for sent in X:
        temp = sent.split()
        sentences_as_words.append(temp)
    for sent in sentences_as_words:
        for word in sent:
            if word_to_index.get(word,None) is None:
                word_to_index[word] = count
                count +=1
    index_to_word = {v:k for k,v in word_to_index.items()}
    sentences=[]
    for i in range(len(sentences_as_words)):
        temp = [word_to_index[w] for w in sentences_as_words[i]]
        sentences.append(temp)


    return sentences_as_words,sentences,word_to_index

def data_prep_ELMo(train_x,train_y,test_x,test_y,max_len):

    INDEX_FROM = 3
    word_to_index = imdb.get_word_index()
    word_to_index = {k:(v+INDEX_FROM) for k,v in word_to_index.items()}

    word_to_index["<START>"] =1
    word_to_index["<UNK>"]=2

    index_to_word = {v:k for k,v in word_to_index.items()}

    sentences=[]
    for i in range(len(train_x)):
        temp = [index_to_word[ids] for ids in train_x[i]]
        sentences.append(temp)

    test_sentences=[]
    for i in range(len(test_x)):
        temp = [index_to_word[ids] for ids in test_x[i]]
        test_sentences.append(temp)

    train_text = [' '.join(sentences[i][:max_len]) for i in range(len(sentences))]
    train_text = np.array(train_text, dtype=object)[:, np.newaxis]
    train_label = train_y.tolist()

    test_text = [' '.join(test_sentences[i][:500]) for i in range(len(test_sentences))]
    test_text = np.array(test_text , dtype=object)[:, np.newaxis]
    test_label = test_y.tolist()

    return train_text,train_label,test_text,test_label


def building_word_vector_model(option,sentences,embed_dim,workers,window,y_train):
    """
        Builds the word vector
        Args:
            type = {bool} 0 for Word2vec. 1 for gensim Fastext. 2 for Fasttext 2018.
            sentences = {list} list of tokenized words
            embed_dim = {int} embedding dimension of the word vectors
            workers = {int} no. of worker threads to train the model (faster training with multicore machines)
            window = {int} max distance between current and predicted word
            y_train = y_train
        Returns:
            model = Word2vec/Gensim fastText/ Fastext_2018 model trained on the training corpus
    """
    if option == 0:
        print("Training a word2vec model")
        model = Word2Vec(sentences=sentences, size = embed_dim, workers = workers, window = window)
        print("Training complete")

    elif option == 1:
        print("Training a Gensim FastText model")
        model = FastText(sentences=sentences, size = embed_dim, workers = workers, window = window)
        print("Training complete")

    elif option == 2:
        print("Training a Fasttext model from Facebook Research")
        y_train = ["__label__positive" if i==1 else "__label__negative" for i in y_train]

        with open("imdb_train.txt","w") as text_file:
            for i in range(len(sentences)):
                print(sentences[i],y_train[i],file = text_file)

        model = fasttext.skipgram("imdb_train.txt","model_ft_2018_imdb",dim = embed_dim)
        print("Training complete")

    return model

def padding_input(X_train,X_test,maxlen):
    """
        Pads the input upto considered max length
        Args:
            X_train = tokenized train data
            X_test = tokenized test data
        Returns:
            X_train_pad = padded tokenized train data
            X_test_pad = padded tokenized test data
    """

    X_train_pad = pad_sequences(X_train,maxlen=maxlen,padding="post")

    X_test_pad = pad_sequences(X_test,maxlen=maxlen,padding="post")

    return X_train_pad,X_test_pad


def ELMoEmbedding(x):
    elmo_model = hub.Module("https://tfhub.dev/google/elmo/1", trainable=True)
    return elmo_model(tf.squeeze(tf.cast(x, tf.string)), signature="default", as_dict=True)["default"]

def prepare_embedding_matrix(model_wv, tokenizer_dict):
  '''
    takes the word vector model and the vocabulary and build an embedding matrix
  '''
  embedding_matrix = [0] * len(tokenizer_dict)
  for word, index in tokenizer_dict.items():
    embedding_matrix[index] = model_wv[word]
  
  return embedding_matrix

# %% [markdown]
# # Building the embedding model

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
padding_input,prepare_data_for_word_vectors_imdb,ELMoEmbedding,data_prep_ELMo


def json_to_dict(json_set):
    for k,v in json_set.items():
        if v == "True":
            json_set[k]= True
        elif v == "False":
            json_set[k]=False
        else:
            json_set[k]=v
    return json_set

model_config = {
    "epochs":10,
    "batch_size":1024,
    "loss":"binary_crossentropy",
    "optimizer":"adam",
    "metrics":["accuracy"]
}

params_set = {
    "embed_dim":300,
    "split_ratio":0.33,
    "max_len":200,
    "vocab_size":10000,
    "trainable_param":"False",
    "option":2,
    "workers":3,
    "window":1

}

'''
    X = text data column
    y = label column(0,1 etc)

'''
if params_set["option"]in [0,1,2]:
    
    # for other data:
    
    X = ["this is a sentence","this is another sentence by me","yet another sentence for training","one more again"]
    y=np.array([0,1,1,0])

    sentences_as_words,sentences,word_ix = prepare_data_for_word_vectors(X)
    print("sentences loaded")
    model_wv = building_word_vector_model(params_set["option"],sentences,params_set["embed_dim"],
                                       params_set["workers"],params_set["window"],y)


    print("word vector model built")
    x_train, x_test, y_train, y_test = train_test_split(sentences, y, test_size=params_set["split_ratio"], random_state=42)
    print("Data split done")
    
    x_train_pad,x_test_pad = padding_input(x_train,x_test,params_set["max_len"])
    #test if the embedding model loaded properly
    print(model_wv['book'])
  

else:
    x_train,x_test,y_train,y_test = load_data(params_set["vocab_size"],params_set["max_len"])

    train_text,train_label,test_text,test_label = data_prep_ELMo(x_train,y_train,x_test,y_test,params_set["max_len"])
# Out:
# sentences loaded
# Training a Fasttext model from Facebook Research
# Training complete
# word vector model built
# Data split done
# [-0.0007892233552411199, 0.0007709571509622037, -0.0011394474422559142, -6.149883847683668e-05, -0.0004190277250017971, -0.00015407467435579747, 0.000739998125936836, -0.0009557089651934803, 0.0006610866985283792, 0.0001075418695108965, 0.00020191243675071746, -0.0006058664876036346, 8.142238948494196e-05, 0.0011675929417833686, -0.00044347657239995897, 0.0002213664847658947, 0.0007722352747805417, -0.0006468711653724313, -0.00022746443573851138, 0.0006329210009425879, 0.0006958863814361393, 0.0006503764889203012, -0.0004064161912538111, 0.000579734449274838, -0.0005881009274162352, -0.00016029154357966036, 1.3961725016997661e-05, -0.0003986213414464146, 0.001101066591218114, -0.0010581912938505411, -0.0005327753024175763, 0.0007579241646453738, 4.94138794238097e-06, -0.0005471291369758546, -0.00047595417709089816, 0.00021494911925401539, -0.00045667984522879124, -0.0007105052354745567, 0.0005364894168451428, -0.0007852270500734448, -0.0002787609992083162, -0.0011457435321062803, 0.0008689519017934799, 0.00059997767675668, 0.0003583352954592556, -0.0005411055753938854, 0.0007904841913841665, -0.00012234649329911917, -0.0007265419117175043, -0.0001005028243525885, -0.0014221578603610396, 0.0009389580227434635, -0.0011251101968809962, 0.0005731033161282539, 0.0007943887612782419, -0.0005761288921348751, -0.0004686551110353321, 0.00032962902332656085, 0.0002990222710650414, -0.0013512992300093174, 0.0005723302601836622, -0.00014595060201827437, 0.0001396966545144096, -0.0005029033636674285, 0.0002262031484860927, -0.00041839751065708697, 4.3874391849385574e-05, 0.0003070109523832798, 0.0005011284374631941, -0.001993539510294795, -0.0005630136583931744, 0.00043953192653134465, 0.00029674716643057764, -0.0005581444129347801, 0.00023936755314935, 0.00015645848179701716, 0.00042818227666430175, -0.00010769810614874586, -0.0006340120453387499, 0.0001647104072617367, -0.000331865536281839, 0.00040782810538075864, -0.0005681967013515532, -4.057225305587053e-05, -0.0004144883423577994, -0.00046169196139089763, -0.000161753996508196, -3.6227495002094656e-05, 0.00039209547685459256, 0.00019278214313089848, 0.0005609019426628947, -0.0008231507963500917, -0.0011492471676319838, -0.001062926952727139, -7.817079676897265e-06, -0.0011068437015637755, -0.0002474640205036849, -0.00015694540343247354, 0.00017604730965103954, 0.0007569993031211197, -0.0007768707582727075, 0.0006196675822138786, -0.0003985063813161105, 0.00015971371612977237, 0.00021047645714133978, -0.0002419163065496832, -0.00010821012983797118, 0.0006711636087857187, -0.0013505466049537063, -0.0001328861981164664, 0.000871599477250129, 5.622231401503086e-05, 0.0002960127894766629, -0.00037873093970119953, -0.00019723514560610056, -0.0009063500910997391, 0.0004373978008516133, -8.666068606544286e-05, -0.00043716057552956045, -4.129923399887048e-05, 0.0008509945473633707, 0.001492880517616868, -0.0002569481439422816, 9.392160427523777e-05, -0.0004308929783292115, -0.00030224720831029117, 0.0008184552425518632, 0.0005053036729805171, -7.753135287202895e-05, 0.001474205288104713, -0.0008864099509082735, -0.0007902970537543297, 0.00018528160580899566, 0.0010072712320834398, -0.0002371948939980939, 3.159495463478379e-05, -0.0011096775997430086, -0.00034323634463362396, 0.0002943254658021033, 0.0008637012797407806, -1.85225853783777e-05, 5.709240440410213e-07, 0.000392628280678764, 0.0008312868885695934, -0.00046620090142823756, -0.0013147552963346243, -0.00023010004952084273, 0.0003451875818427652, -0.001156166079454124, -8.480082760797814e-05, -0.0003409962810110301, 0.00021993705013301224, 3.056841887882911e-05, -0.0006631221040152013, 0.0009508251096121967, -9.428368502994999e-05, 0.0005294557777233422, -2.2986578187556006e-05, -0.0009747477597557008, -2.3694872652413324e-05, 0.0007586123538203537, -0.00045691183186136186, 0.0012232685694471002, 0.00047627027379348874, -8.374699245905504e-05, 0.0002840329834725708, 0.00046326807932928205, -4.748055289383046e-05, 0.001092021469958126 ...

# %% [markdown]
# ## Optionally, limit the size of the training set for faster training

# %%
# read the json file
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# storing the captions and the image name in vectors
all_captions = []# only has the captions
all_img_name_vector = []# only has the paths

for annot in annotations['annotations']:
    #have to see if each image has 1:5 relation with the captions and have to incorporate that somehow!
    caption = '<start> ' + annot['caption'] + ' <end>'
    image_id = annot['image_id']
    full_coco_image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (image_id)
    
    all_img_name_vector.append(full_coco_image_path)
    all_captions.append(caption)

# shuffling the captions and image_names together
# setting a random state
train_captions, img_name_vector = shuffle(all_captions,
                                          all_img_name_vector,
                                          random_state=1)

# selecting the first 10000 captions from the shuffled set
num_examples = 32000
train_captions = train_captions[:num_examples]
img_name_vector = img_name_vector[:num_examples]

# %% [markdown]
# **DELETE STUFF NOT NEEDED!**

# %%
del all_captions
del all_img_name_vector
del annotations

# %% [markdown]
# ## Preprocess the images using InceptionV3

# %%
def load_image_inception(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path
  
def load_image_resnet(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (224, 224))
    img = tf.keras.applications.resnet50.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ## Initialize InceptionV3/Resnet and load the pretrained Imagenet weights

# %%
def initialize_inception_model():
  image_model = tf.keras.applications.InceptionV3(include_top=False, 
                                                weights='imagenet')
  new_input = image_model.input
  hidden_layer = image_model.layers[-1].output

  image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
  return image_features_extract_model

def initialize_resnet_model():
  image_model = tf.keras.applications.resnet50.ResNet50(include_top=False, 
                                                weights='imagenet')
  new_input = image_model.input
  hidden_layer = image_model.layers[-1].output

  image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
  return image_features_extract_model

image_features_extract_model = initialize_resnet_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:642: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W0326 15:07:07.725584 139987048392576 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:642: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step

# %%
# image_features_extract_model.summary()

# %% [markdown]
# **Code to cache the inceptionV3/resnet
# tensors**
#
# ---

# %%
'''experimental stuff!!'''
'''
https://github.com/tensorflow/tensorflow/issues/25731
https://github.com/tensorflow/tensorflow/issues/25808
'''


# getting the unique images
encode_train = sorted(set(img_name_vector))

# feel free to change the batch_size according to your system configuration
# a generator which yields 16 images at one shot along with its path
image_dataset = tf.data.Dataset.from_tensor_slices(
                                encode_train).map(load_image_resnet).batch(16)

for img, path in image_dataset:
  #image_features_extract_model is the InceptionV3/Resnet stack which gives out tensors in the end 
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features, 
                              (batch_features.shape[0], -1, batch_features.shape[3]))
  

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())

# %% [markdown]
# **DELETE STUFF NOT NEEDED!**

# %%
del encode_train
del image_dataset

# %% [markdown]
# ## Preprocess and tokenize the captions

# %%
# This will find the maximum length of any caption in our dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# The steps above is a general process of dealing with text processing
# choosing the top 5000 words from the vocabulary
top_k = 6500
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k, 
                                                  oov_token="<unk>", 
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~ ')
tokenizer.fit_on_texts(train_captions)
train_seqs = tokenizer.texts_to_sequences(train_captions)

cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')
tokenizer.word_index['<pad>'] = 0

# %%
# calculating the max_length 
# used to store the attention weights
max_length = calc_max_length(train_seqs)
max_length
# Out:
# 49

# %%
# prepare the embedding matrix
embedding_matrix = prepare_embedding_matrix(model_wv,tokenizer.word_index)

# %% [markdown]
# ## Split the data into training and testing

# %%
# Create training and validation sets using 80-20 split
img_name_train, img_name_testval, cap_train, cap_testval = train_test_split(img_name_vector, 
                                                                    cap_vector, 
                                                                    test_size=0.2, 
                                                                    random_state=0)
img_name_test,img_name_val,cap_test,cap_val = train_test_split(img_name_testval,cap_testval,test_size = 0.5,random_state = 0)

# %% [markdown]
# **DELETE STUFF NOT NEEDED!**

# %%
del img_name_vector
del cap_vector
del train_seqs

# %% [markdown]
# **MODEL HYPERPARAMETERS AND CONFIG PARAMS**

# %%
# feel free to change these parameters according to your system's configuration

BATCH_SIZE = 16
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = len(tokenizer.word_index)
# shape of the vector extracted from InceptionV3 is (64, 2048)
# these two variables represent that
features_shape = 2048
attention_features_shape = 64

model_config = {
    'dim_cnn': 4096,
    'optimizer': 'adam',
    'batch_size': BATCH_SIZE,
    'epochs': 15,
    'output_dim': 1024,
    'dim_word': 300,
    'lrate': 0.05,
    #'lrate': 0.0005,
    'max_cap_length' : max_length,
    'margin': 0.05,
    #for resnet50 the shape is 100,2048
    'image_input_shape':(49,features_shape)
}

# %% [markdown]
# **CREATING THE DATASET GENERATOR USING tf.data.Dataset**

# %%
# loading the numpy files 
def map_func(cap,img_name):
  #caching the features stored in the .npy files
  image_tensor = np.load(img_name.numpy().decode('utf-8') +'.npy')
  return cap.numpy(), image_tensor

#old code for non caching of features
#   batch_features = image_features_extract_model(tf.expand_dims(load_image(img_name)[0], axis = 0))
#   image_tensor = tf.reshape(batch_features, (batch_features.shape[0], -1, batch_features.shape[3]))
#   image_tensor = tf.squeeze(image_tensor)

# %%
#create a simple datagenerator using the coco image features and the captions
def create_data_generator(cap, img_name):
  dataset = tf.data.Dataset.from_tensor_slices((cap,img_name))

  # using map to load the numpy files in parallel
  # NOTE: Be sure to set num_parallel_calls to the number of CPU cores you have
  # https://www.tensorflow.org/api_docs/python/tf/py_func
  dataset = dataset.map(lambda item1, item2: tf.py_function(
            map_func, [item1, item2], [tf.int32, tf.float32]), num_parallel_calls=8)

  # shuffling and batching
  dataset = dataset.shuffle(BUFFER_SIZE)
  # https://www.tensorflow.org/api_docs/python/tf/contrib/data/batch_and_drop_remainder
  dataset = dataset.batch(BATCH_SIZE)
  dataset = dataset.repeat()
  dataset = dataset.prefetch(1)

  return dataset

# %%
#using the above data_generator to yield training data to be fitted to the model at training time
def train_generator():
  train_iter = create_data_generator(cap_train, img_name_train).make_one_shot_iterator()
  while True:
    caps, imgs = train_iter.get_next()
    batch = [caps.numpy(),imgs.numpy()]
    dummy = np.zeros(shape=(BATCH_SIZE, model_config['output_dim'] * 2))    
    yield batch, dummy
    

def test_generator():
  test_iter = create_data_generator(cap_test, img_name_test).make_one_shot_iterator()
  while True:
    caps, imgs = test_iter.get_next()
    batch = [caps.numpy(),imgs.numpy()]
#     dummy = np.zeros(shape=(BATCH_SIZE, model_config['output_dim'] * 2))    
    yield batch
  
  
def val_generator():
  val_iter = create_data_generator(cap_val, img_name_val).make_one_shot_iterator()
  while True:
    caps, imgs = val_iter.get_next()
    batch = [caps.numpy(),imgs.numpy()]
    dummy = np.zeros(shape=(BATCH_SIZE, model_config['output_dim'] * 2))    
    yield batch, dummy

# %%
t = train_generator()

# %% [markdown]
# **TESTING THE DATASET GENERATOR**

# %% [markdown]
# ##Model

# %%
#A GRU WRAPPER
def gru(units):

  if tf.test.is_gpu_available():
    return CuDNNGRU(units, 
                    return_sequences=False, 
                    return_state=False, 
                    recurrent_initializer='glorot_uniform')
  else:
    return GRU(units, 
                 return_sequences=False, 
                 return_state=False, 
                 recurrent_activation='sigmoid', 
                 recurrent_initializer='glorot_uniform')
  
  
def lstm(units):  
  if tf.test.is_gpu_available():
    return CuDNNLSTM(units, 
                    return_sequences=False, 
                    return_state=True, 
                    recurrent_initializer='glorot_uniform')
  else:
    return LSTM(units, 
                 return_sequences=False, 
                 return_state=True, 
                 recurrent_activation='sigmoid', 
                 recurrent_initializer='glorot_uniform')
  

#RELATED TO LOSS FUNCTIONS
def compute_errors(s_emb, im_emb):
    """ Given sentence and image embeddings, compute the error matrix """
    errors = [order_violations(x, y) for x in s_emb for y in im_emb]
    return np.asarray(errors).reshape((len(s_emb), len(im_emb)))

def order_violations(s, im):
    """ 
    Computes the order violations (Equation 2 in the paper) 
    i.e this is the similiarity score -S(c,i)
    """
    
    return np.power(np.linalg.norm(s - im),2)


def l2norm(X):
    """ Compute L2 norm, row-wise """
    norm = tf.reduce_sum(tf.sqrt(tf.pow(X, 2)), 1)
    X /= norm[:, None]
    return X



def contrastive_loss(labels, predict):
    """For a minibatch of sentence and image embeddings, compute the pairwise contrastive loss, refer the original report to understand this better"""
    global model_options
    margin = model_config['margin']
    predict = tf.identity(predict)
    s, im = tf.split(predict, [model_config['output_dim'], model_config['output_dim']], axis = -1)
    print("s=",s)
    print("im=",im)

    im2 = tf.expand_dims(im,axis=0)
    s2 = tf.expand_dims(s,axis=1)
#     print("im2=",im2)
#     print("s2=",s2)

    errors = tf.reduce_sum(tf.pow(tf.subtract(im2, s2), 2), 2)
    diagonal = tf.diag_part(errors)
    cost_s = tf.maximum(tf.constant(0, dtype=tf.float32), tf.add(tf.subtract(margin, errors), diagonal))
    diagonal2 = tf.reshape(diagonal, [-1, 1])
#     print("\n\n\n\n")
    # print("margin.shape = ", margin.shape)
#     print("errors.shape = ", errors.shape)
#     print("diagonal.shape = ", diagonal.shape)
#     print("diagonal2.shape = ", diagonal2.shape)
#     print("\n\n\n\n")
    cost_im = tf.maximum(tf.constant(0, dtype=tf.float32), tf.add(tf.subtract(margin, errors), diagonal2))
    cost_tot = tf.add(cost_s, cost_im)
#     print("cost_s=",cost_s)
#     print("cost_im=",cost_im)
#     print("cost_tot before=",cost_tot)
    zeroes = tf.zeros((model_config['batch_size'],), tf.float32)
#     print("zeroes=",zeroes)
    cost_tot = tf.linalg.set_diag(cost_tot, zeroes)
#     print("cost_tot after=",cost_tot)
    return tf.reduce_sum(cost_tot)

# %% [markdown]
# **MODEL DEFINITION**

# %%
#IMAGE SIDE (DECODER SIDE)
print("image model loading...")
image_input = Input(shape=model_config['image_input_shape'], name='image_input')
X = Flatten()(image_input)
X = Dense(model_config['output_dim'])(X)
emb_image = Lambda(lambda x: l2norm(x))(X)   #the final embedding representation of the image
print("image",emb_image)
#CAPTION SIDE (ENCODER SIDE)
print ("Text model loading..")
cap_input = Input(shape=(model_config['max_cap_length'],), dtype='float32', name='cap_input')
X = Masking(mask_value=0,input_shape=(model_config['max_cap_length'], model_config['output_dim']))(cap_input)#(X)
#maybe it should be this...
#this compiles.....YAY!!
# X = Masking(mask_value=0,input_shape=(model_config['max_cap_length'],))(cap_input)


X = Embedding(output_dim=model_config['dim_word'], input_dim=len(tokenizer.word_index), input_length=model_config['max_cap_length'], weights=[embedding_matrix])(cap_input)

# X = gru(model_config['output_dim'])(X)
_,for_state_h,for_state_c,bac_state_h,bac_state_c=Bidirectional(lstm(model_config['output_dim']))(X)
# _, state_h, state_c = 
mergedstates = concatenate([for_state_h,for_state_c,bac_state_h,bac_state_c])
X= Dense(model_config['output_dim'])(mergedstates)


emb_cap = Lambda(lambda x: l2norm(x))(X)   #the final embedding representation of the catption
print("capt",emb_cap)
#CONCATENATING BOTH MODAL REPRESENTATIONS
print ("loading the joined model")
merged = concatenate([emb_cap, emb_image])

#MODEL INPUT/OUTPUT DEFINTION
model = Model(inputs=[cap_input, image_input], outputs=[merged])

#MODEL COMPILING STEP
print ("compiling the model")
model.compile(optimizer=model_config['optimizer'], loss=contrastive_loss)
# Out:
# image model loading...
# image Tensor("truediv_10:0", shape=(?, 1024), dtype=float32)
# Text model loading..
# capt Tensor("truediv_11:0", shape=(?, 1024), dtype=float32)
# loading the joined model
# compiling the model
# s= Tensor("loss_15/concatenate_9_loss/split:0", shape=(?, 1024), dtype=float32)
# im= Tensor("loss_15/concatenate_9_loss/split:1", shape=(?, 1024), dtype=float32)

# %% [markdown]
# **MODEL ARCHITECTURE SUMMARY**

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cap_input (InputLayer)          (None, 49)           0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 49, 300)      2543400     cap_input[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) [(None, 2048), (None 10862592    embedding_4[0][0]
# __________________________________________________________________________________________________
# image_input (InputLayer)        (None, 49, 2048)     0
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 4096)         0           bidirectional_4[0][1]
#                                                                  bidirectional_4[0][2]
#                                                                  bidirectional_4[0][3]
#                                                                  bidirectional_4[0][4]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 100352)       0           image_input[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1024)         4195328     concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1024)         102761472   flatten_4[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1024)         0           dense_9[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1024)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 2048)         0           lambda_9[0][0]
#                                                                  lambda_8[0][0]
# ==================================================================================================
# Total params: 120,362,792
# Trainable params: 120,362,792
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **LOAD THE SAVED MODEL WEIGHTS BEFORE RETRAINING**

# %%
#Setup between colab and drive and fuse or something!!
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131323 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.1-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.1-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#load from model.json and try stuff...
root_path = "drive/DLSIR_model_weights/"
json_file_path = root_path+"model(resnet+fastext+bidir).json"
weights_file_path = root_path+"model(resnet+fastext+bidir).h5"

from tensorflow.keras.models import model_from_json
# load json and create model
with open(json_file_path, 'r') as json_file:
  loaded_model_json = json_file.read()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(weights_file_path)
model = loaded_model
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
#recompile this loaded model
model.compile(optimizer=model_config['optimizer'], loss=contrastive_loss)
# Out:
# s= Tensor("loss_1/concatenate_1_loss/split:0", shape=(?, 1024), dtype=float32)
# im= Tensor("loss_1/concatenate_1_loss/split:1", shape=(?, 1024), dtype=float32)

# %%
Epoch 3/15
10/10 [==============================] - 30s - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00

# %% [markdown]
# **TIME TO FIT THE DATA AND TRAIN THE MODEL!**

# %%
print(int(len(cap_train)// BATCH_SIZE))
print(int(len(cap_val)//BATCH_SIZE))
# Out:
# 1600
# 200

# %%
#fitgenerator
train_gen = train_generator()
# val_gen = val_generator()
train_hist = model.fit_generator(train_gen, steps_per_epoch=int(len(cap_train)// BATCH_SIZE),verbose=1,epochs = 5)
# train_hist = model.fit_generator(train_gen, steps_per_epoch=int(len(cap_train)// BATCH_SIZE),validation_data = val_gen ,validation_steps = int(len(cap_val)//BATCH_SIZE),verbose=1,epochs = 10)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 1600/1600 [==============================] - 468s 293ms/step - loss: 16.6831
# Epoch 2/5
# 1600/1600 [==============================] - 457s 286ms/step - loss: 13.6309
# Epoch 3/5
# 1600/1600 [==============================] - 455s 284ms/step - loss: 11.4491
# Epoch 4/5
# 1600/1600 [==============================] - 459s 287ms/step - loss: 7.0393
# Epoch 5/5
# 1600/1600 [==============================] - 463s 289ms/step - loss: 5.7160

# %% [markdown]
# ! pwd

# %% [markdown]
# **SAVE THE WEIGHTS INTO DRIVE AND BACK**

# %%
#save the weights
model_json = model.to_json()
with open("drive/DLSIR_model_weights/model(resnet+fastext+bidir).json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("drive/DLSIR_model_weights/model(resnet+fastext+bidir).h5")
print("Saved model to drive")
# Out:
# Saved model to drive

# %%
for w in model.get_weights():
  print(w.shape)
# Out:
# (8478, 300)
# (300, 4096)
# (1024, 4096)
# (8192,)
# (300, 4096)
# (1024, 4096)
# (8192,)
# (4096, 1024)
# (1024,)
# (100352, 1024)
# (1024,)

# %% [markdown]
# **EVALUATION HELPER FUNCTIONS**

# %%
def t2i(c2i,k):
    """
    Text->Images (Image Search)
    c2i: (N, N) matrix of caption to image errors
    """

    '''
    for Sumanth!:
    
    in our case c2i is the test_errs matrix of size N*N where N is the size of the test datset and each value test_errs[i][j]= the order_violations score
    if N == 1000
    ranks is an numpy.array of size 1000
    
    for each row i in this matrix:(row meaning for one caption all the similarity values with the remiaing 1000 images)
      do an argsort ( sort it but show an array with the indices ka order instead)
      find the rank of this i'th caption among 1000 by searching the index of that i'th column/image ( ideally a rank of 1 means that the model is learing properly cause if the score is 0 that means its a perfect fit!)
    
    recall@k is now that percentage of how many such captions fall below the rank of k .......out of all the images..
    
    
    the function i2t is like take one image and see for all captions!
    '''

    
    
    ranks = np.zeros(c2i.shape[0])

    for i in range(len(ranks)):
        d_i = c2i[i]
        inds = np.argsort(d_i)

        rank = np.where(inds == int(i))[0][0]
        ranks[i] = rank

        def image_dict(k):
            return {'id': k, 'score': float(d_i[k])}

    r10 = 100.0 * len(np.where(ranks < k)[0]) / len(ranks)
    meanr = ranks.mean() + 1

    return map(float, [r10, meanr])




def i2t(c2i,k):
    """
    Image->Texts (Text Search)
    c2i: (N, N) matrix of caption to image errors
    """

    ranks = np.zeros(c2i.shape[1])

    for i in range(len(ranks)):
        d_i = c2i[:, i]
        inds = np.argsort(d_i)

        rank = np.where((inds).astype(int) == i)[0][0]
        ranks[i] = rank

    # Compute metrics
    r10 = 100.0 * len(np.where(ranks < k)[0]) / len(ranks)
    meanr = ranks.mean() + 1
    return map(float, [r10, meanr])

  
def eval_model(k):
  "compute recall@k"
  weights = model.get_weights()

  emb_w = weights[0]
  im_w = weights[9]
  im_b = weights[10]
  gru_weights = weights[1:9]

  test_model_im = Model(inputs=image_input, outputs=emb_image)
  test_model_im.set_weights([im_w, im_b])
  test_model_im.compile(optimizer='adam', loss="mse")#contrastive_loss)
  test_model_cap = Model(inputs=cap_input, outputs=emb_cap)
  test_model_cap.set_weights([emb_w]+ gru_weights)
  test_model_cap.compile(optimizer='adam', loss="mse")#contrastive_loss)

  gen = test_generator()

  test_cap = []
  test_im = []
  
  for i in range(len(cap_val)//BATCH_SIZE):
    data = next(gen)
    test_cap.extend(data[0])
    test_im.extend(data[1])


  pred_cap = test_model_cap.predict(np.array(test_cap))
  pred_im = test_model_im.predict(np.array(test_im))
  test_errs = compute_errors(pred_cap, pred_im)
  print("The shape of testerrs is",test_errs.shape)
  print(test_errs[0])

  r10_c, rmean_c = t2i(test_errs,k)
  r10_i, rmean_i = i2t(test_errs,k)
  return [[r10_c,rmean_c],[r10_i,rmean_i]]

# %%
k=10
caption_stats,image_stats = eval_model(k)
# Out:
# The shape of testerrs is (3200, 3200)
# [0.02952804 0.12292565 0.13930271 ... 0.1738881  0.25460623 0.243089  ]

# %%
print("caption recall @",k," is=>",caption_stats[0])
print("caption mean @",k," is=>",caption_stats[1])
print("image recall @",k," is=>",image_stats[0])
print("image mean @",k," is=>",image_stats[1])
# Out:
# caption recall @ 10  is=> 3.59375
# caption mean @ 10  is=> 307.94
# image recall @ 10  is=> 2.4375
# image mean @ 10  is=> 310.1590625

# %% [markdown]
# LETS TRY GIVING A CUSTOM CAPTION INPUT NOW!

# %%
def get_test_models_from_weights():
  weights = model.get_weights()

  emb_w = weights[0]
  im_w = weights[9]
  im_b = weights[10]
  gru_weights = weights[1:9]

  test_model_im = Model(inputs=image_input, outputs=emb_image)
  test_model_im.set_weights([im_w, im_b])
  test_model_im.compile(optimizer='adam', loss="mse")#contrastive_loss)
  test_model_cap = Model(inputs=cap_input, outputs=emb_cap)
  test_model_cap.set_weights([emb_w]+ gru_weights)
  test_model_cap.compile(optimizer='adam', loss="mse")#contrastive_loss)
  return test_model_cap,test_model_im

# %%
test_model_cap , test_model_im = get_test_models_from_weights()
# pred_cap = test_model_cap.predict(np.array([test_c]))
# pred_im = test_model_im.predict(np.array([test_i]))
# order_violations(pred_cap, pred_im)

# %%
def gimme_image(number):
#   im = Image.open(img_name_val[number])
  test_i = mpimg.imread(img_name_val[number])
  plt.imshow(test_i)
  
  return np.array([np.load(img_name_val[number] +'.npy')])

# %%
def gimme_caption(number):
  test_c = cap_val[number]
  word_map = dict(map(reversed, tokenizer.word_index.items()))
  s = ' '.join([ word_map[i] for i in test_c ])
  print("caption:",s)
#   print(test_c)
  return np.array([test_c])

# %%
# TODO: rewrite ( use tokenizer )
def caption_to_post_padding(caption):
  caption = '<start> ' + caption + ' <end>'
  tokens = caption.split()
  pad_amount = max_length-len(tokens)
  padding = ['<pad>']*pad_amount
  tokens.extend(padding)
  return tokens

def caption_to_embedding(caption):
  def get_word_index(x):
    try:
      return tokenizer.word_index[x]
    except:
      return 0#out of vocabulary have to look into this later
  
  tokens = caption_to_post_padding(caption)
  index = list(map(lambda x:get_word_index(x),tokens))
  return np.array(index)
   
a = caption_to_embedding("white toilet in a red boat")
print(a.shape)
# Out:
# (49,)

# %%
def query(cap,img):
  return order_violations(test_model_cap.predict(cap), test_model_im.predict(img))

# %% [markdown]
# AN EXAMPLE OF  HOW OUR MODEL WORKS (Random image<-->Random caption)

# %%
query(gimme_caption(25),gimme_image(25) )
# Out:
# caption: <start> a desk with pictures a vase and a ceramic shoe <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# 0.03354507725816802

# %%
query(gimme_caption(50),gimme_image(27) )
# Out:
# caption: <start> a man riding skis down a snow covered slope <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# 0.11557455026523034

# %% [markdown]
# A LOOK INTO WHAT OUR TEST DATASET HAS

# %%
import random
def show_random_captions_from_test_dataset(size=100):
  test_dataset_indices = [i for i in range(3200)]
  l = random.sample(test_dataset_indices,size)
  for i in l:
    gimme_caption(i)
    
show_random_sample_from_test_dataset(250)
# Out:
# caption: <start> a little girl wearing a red dress <unk> a large plastic container from a refrigerator <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a small alarm clock on top of a stack of books <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man in the air skating on the <unk> <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> people getting ready to get onto a bus <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a plane sitting on a runway waiting to take off <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a steak sandwich with a cup of green sauce on a white plate <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a person with a knife near a cutting board on a counter <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man sitting at a table with a pizza and a drink <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man putting a spoon in his mouth while sitting at a table <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bathroom under construction with wall studs exposed <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a young girl looking at her birthday cupcakes <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> taxi cab stops at a red light on a city street <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a close up of a cat wearing read bunny ears <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bear walking around a well of water <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> elephants walk on a street in from of a building while the <unk> image is reflected in a mirror <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a couple cows in a pasture with a windmill <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> someone is skiing and jumping high off a mountain <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a destroyed bathroom with a window and toilet <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man dressed in a black suit with a black plastic mask holding a green ball and looking very serious <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a dog and a cat are <unk> on a couch <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the opened suitcase is on the floor next to a jacket <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a little kid sitting at a table with donuts and drinks <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a female in a blue bathing suit a fence and some buildings <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> colorful kites stream over the water while crowds stand on the bank <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bowl filled with some veggies and pasta <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the television has two candles lit on each side of it <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a baseball pitcher wearing a white uniform on the mound <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> this plate has a bowl of soup and two scoops of crab salad with tomatoes on top <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> cat is laying in front of computer screen watching keyboard <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> three people sitting around a table eating and drinking <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a black and white photo of a plant against a wall <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> several people are parasailing near and landing on a beach <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man that is posing with sunglasses on and holding a frisbee <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a street sign with two signs hanging off of it's sides <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a double deckered bus on a narrow road <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> an eggs and bacon sandwich sits on a plate <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man with a sandwich in his hands <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a train station with several doors and two people near them <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two benches at the end of a row of hedges <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a fridge door is open and full of condiments <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> various pieces of food in a cooking pan <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a sign indicating what time street sweeping takes place <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> theres a fruit stand with lots of fruit <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a sink with mirrors on both sides of it <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a picture of two horses that are eating something <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> some people with their boats and some have colored umbrellas <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a fridge has a few notes and magnets on its doors <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> zebras in large open field with dried grasses <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a street is filled with colorful umbrellas in the air <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> guy acting surprised as the waitress places a food item on his plate <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a black dog and a brown dog are on a boat <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a black microwave sitting on top of a wooden counter <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a flooded street with tree and street sign under water <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cat stares up besides the home entrance <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman holding a tennis racket on a tennis court <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a flooded street with trees and street signs to <unk> the water level <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a hallway lined with doors and filled with suitcases <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the horse trots across the meadow as his darker compatriot follows behind <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> an empty bathroom with the toilet lid up <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a platter filled with different types of donuts <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a baseball player holding a bat while standing next to a base <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a dog and a cat are looking at the snowy front yard through a glass door <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a <unk> doll that is on some skates in a room <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a green train next to train station with clock <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> someone uses a knife and fork to eat a pizza on a plate <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman in a graduation gown posing with a man <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a couple of cats just hanging out on some shoe shelves <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a vintage photo of a person holding an umbrella <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a plate of pancakes chicken and broccoli sits on a table <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a hand holding a cellphone and a man using a computer <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> some women in the street wearing <unk> clothing <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a group of people on snow skis participating in a race <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a sky full of kites on a sunny day at the beach <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a plate of eggs toast potato wedges and orange slices <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the man walks down a path through a snow covered park <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> an eagle is perched on a high branch <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman standing on top of a tennis court <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> this is a patriotic three tiered cake display <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a large fluffy cat laying in front of a mirror <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a street sign of ne 5th st and the back of a stop sign <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a long loaf of bread cut into slices <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> birds sitting on top of a walking elephant <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a line of people waiting at a food truck <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a person standing on top of a snow covered slope <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cat sitting on a bath rug next to a pile of clothes <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman standing in a doorway of a bedroom in mount vernon <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man holding a game controller in front of a flat screen tv <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman staring straight ahead while sitting on a bed <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two giraffes standing together near two other animals <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man and woman sitting in chairs talking with a view of the ocean behind them <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a small bird perched on a pile of bird seed <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a lot of bikers going down a concrete road <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman holding a large teddy bear in the middle of a lobby <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bowl full of food and a glass rest on the table <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> several people teach a child how to surf <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man in a suit and tie lying on the grass clutching a bottle of whiskey <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a person is up in the air doing a skiing stunt while people is watching <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the window is open to let in some air <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a toilet sits oddly on a sidewalk in a residential area <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> three surfers in black on a sandy beach <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a view of a dining room with a chandler above the table <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a group of young people playing with frisbee on field <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man using his apple laptop computer in bed <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a boy and a girl eating chips at a party table <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a young man kicking a soccer ball around on a field <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> someone is hanging from a cable with a surf board attached to their feet <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man holding a plate of food that has been shaped into a heart <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a herd of elephants walking along side of a train <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a view of a couple of oranges <unk> in a glass <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a blanket and a cup are lying on a city bench <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man laying in bed underneath a picture hanging from the wall <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a number of people in a field playing tennis <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a large building with a clock hanging on the outside <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a large clock tower is decorated with statues <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two men in room playing game with nintendo wii controllers <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> three small clear vases with pink flowers in them <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two giraffes that appear to have their necks wrapped around each other <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a living area with a desk chair closet and window <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a group of boats floating on top of a river near a city <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a young boy uses scissors on a craft <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a young man riding a skateboard on a paved surface <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman looking down at her child by some giraffes <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a <unk> of items are set out for display <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> an elephant stands and looks through an open doorway <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a possible dead orange cat laying on the side of the road <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a car diving down in old road surrounded by old buildings <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> guy holding a remote on the couch next to another holding a book <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two zebras walk outside on a grassy plain <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a lone zebra is standing by a tree <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a <unk> sign that gives directions to buildings <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a blue traffic sign next to a parked car on a city street <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a zebra standing in the middle of a grass covered field <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a television screen and a table in a room <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a baby elephant sitting on top of another baby elephant <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cluster of red flowers sitting next to a green field <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bathroom sink with toothbrushes and paste on the edge <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> an image of a man that is going down the waves with a surfboard <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a naked woman sitting in a large suitcase <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two elephants standing together in a watering hole <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man in a black jacket is holding a sandwich <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> there are couches and chairs in the room <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the restaurant cane's is right down the street <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a train traveling down tracks next to a forest <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cat that is standing in a window sill <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a table with paper plates that have pizza sitting on them <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> small child skiing down snowy small trail intended for kids <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man standing on a tennis court holding a racquet <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a large brick building features a clock tower and store fronts <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the small dog walks with a frisbee in it's mouth <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a snow boarder stands a top f a hill <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a very big bunch of birds gathered together by the water <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a baseball player at a professional game is bending down to catch the ball <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a white dog wearing a hat and sunglasses laying in the grass <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a single giraffe stand among some busy trees <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a hand holds up a half eaten sandwich as a man sits in the background <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man and woman standing in front of some pizza <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a motorcyclist is taking a turn on a gravel road <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> 4 pictures of some different fruits like bananas and strawberrie <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> there is a woman cooking and a dog sitting by her <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the people are sitting on a couch with food around them <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a whole pizza sitting on a white plate on a table <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cut in half sandwich on a plate <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# ...
# caption: <start> two bears standing up against bars in a cage <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a grey cat sitting behind a window curtain <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bathroom area decorated in all white with lights above the mirror <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cat laying on a bed next to a laptop <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a large white appliance sits on a folding table in a kitchen <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a male in a white shirt is making food in a kitchen <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a group of people playing the nintendo wii <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two people holding each other on the snow posing <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cloth container on the floor holding a variety of office items <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a picture of a public restroom with tiles <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a black bowl filled with meat rice and vegetables <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bike parked next to a surfboard near a building <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a stove and overhead microwave in an empty kitchen <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> two men are smiling for the camera in a crowd of people <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> group of people standing inside a beauty salon together <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a tour bus sitting in a parking lot near a moutain side <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a smiling guy playing with a disc in the grass <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> close up side shot of a giraffe looking over a fence <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a steam engine drives down some tracks through the country <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a toilet without a tank is in a bathroom next to a bathtub <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a police officer in a helmet staring at a motorcycle <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a small child <unk> a bucket to an animal through a fence <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a person riding a skate board at a skate park <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a park bench sitting next to a tree in a park <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man jumping in the air on a skateboard <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a man holding a camera while brushing his teeth <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a harbor surrounded by tall buildings and filled with boats <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bed with a bunch of dead <unk> <unk> on it <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a shirtless man with an umbrella sit before a scene on the wall that also includes an umbrella <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a bus parked on a street next to a sidewalk underneath a tree <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman in a black leather jacket hugging a large black suitcase <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a small boy holds a partially peeled banana <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a person holding a pair of scissors with orange handles <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a little boy is playing on a laptop in the car while a little girl watches <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a street sign lite up next to parked cars <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a dog playing with a ball in the waves <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman swinging at a tennis ball with her racquet <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a street corner with the front of a shop <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> an open living room with couchs and large windows <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> bananas kiwi and other fruits in a bowl <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a close up of a giraffe in a field <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a backed potato is covered in several sauces and seasonings <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a number of zebras behind a fence <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a cat standing on the edge of a sink in a bathroom <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a kitchen with wooden floors and counters painted green <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> five people on skis standing on the snow together <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a red fire hydrant is sitting in between two <unk> trees <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a brown and white cow with horns standing in a field <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a refrigerator sitting in a room next to a window <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> man in kitchen working on multiple sausages <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a sign that uses a clock to advist the store <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> the man jumps the bench on his skateboard <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a dog laying under a blanket in a bed <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# caption: <start> a woman is taking a bite out of some food <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>

# %% [markdown]
# **  RETRIEVE THE TOP 'k' IMAGES GIVEN A CAPTION**

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

def show_top_images_with_scores(combined):
#   fig = plt.figure()
  fig, ax = plt.subplots(len(combined),1, figsize=(15, 15))
  i=0
  for score,img_path in combined:
    print("-"*100)
    print("IMAGE IS ...",img_path)
    img = Image.open(img_path)
    
    ax[i].imshow(img)
    print("SCORE IS ....")
    print(score)
    i+=1

# %%
#caching the test dataset's image embeddings
all_test_images = img_name_val
all_test_image_features = list(map(lambda img_name:np.load(img_name +'.npy'), all_test_images))
imgs_embs = test_model_im.predict(np.array(all_test_image_features))

# %%
print(len(imgs_embs))
print(len(all_test_images))
# Out:
# 3200
# 3200

# %%
'''
1. prepare caption by making it an embedding
2. take the test dataset ka images which has been pased thru the cnn stack and make 2 lists of -1.with all the features -2.with all the corresponding image_names
3. take the test_models and predict for this caption and all images and get a list of similarity scores.
4. zip the list with the similarity scores and the images_names and sort based on the score using "key"
5.pick top k and show as an image
'''
def get_top_k_images(k,caption):
  cap_inp = caption_to_embedding(caption)
  test_model_cap , test_model_im = get_test_models_from_weights()
  #this might fail if so wrap it around a np.array
#   print(cap_inp.shape)
#   print(cap_inp)
#   return 
  cap_emb = test_model_cap.predict(np.array([cap_inp]))
  print("cap_emb is ",cap_emb.shape)
  #refer the above cell
#   all_test_images = img_name_val
#   all_test_image_features = list(map(lambda img_name:np.load(img_name +'.npy'), all_test_images))
#   imgs_embs = test_model_im.predict(np.array(all_test_image_features))


  print("imgs_embs are",imgs_embs.shape)
  similarity_scores = []
  for img_emb in imgs_embs:
    score=order_violations(cap_emb,img_emb)
    similarity_scores.append(score)
  combined = list(zip(similarity_scores,all_test_images))
#   print("combined",len(combined))
#   print(all_test_images.count('/content/train2014/COCO_train2014_000000178244.jpg'))
#   print(combined.count((0.008259380078972145, '/content/train2014/COCO_train2014_000000178244.jpg')))
  topk= sorted(combined, key=lambda x: x[0])[:k]
  print("the sorted order is ",topk)
  show_top_images_with_scores(topk)
  return

# %% [markdown]
# **SOME PREDICTIONS USING OUR MODEL!**

# %%
caption = "cow on field"
get_top_k_images(6,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# combined 3200
# 2
# 2
# the sorted order is  [(0.008259380078972145, '/content/train2014/COCO_train2014_000000178244.jpg'), (0.008259380078972145, '/content/train2014/COCO_train2014_000000178244.jpg'), (0.008747575053538237, '/content/train2014/COCO_train2014_000000474775.jpg'), (0.008933146402569037, '/content/train2014/COCO_train2014_000000526565.jpg'), (0.009478190551515164, '/content/train2014/COCO_train2014_000000376875.jpg'), (0.010097595491858125, '/content/train2014/COCO_train2014_000000309437.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000178244.jpg
# SCORE IS ....
# 0.008259380078972145
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000178244.jpg
# SCORE IS ....
# 0.008259380078972145
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000474775.jpg
# SCORE IS ....
# 0.008747575053538237
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000526565.jpg
# SCORE IS ....
# 0.008933146402569037
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000376875.jpg
# SCORE IS ....
# 0.009478190551515164
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000309437.jpg
# SCORE IS ....
# 0.010097595491858125

# %%
caption = "elephants roaming in the green forest"
get_top_k_images(6,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.00864110449319555, '/content/train2014/COCO_train2014_000000474775.jpg'), (0.009258090841805178, '/content/train2014/COCO_train2014_000000178244.jpg'), (0.009258090841805178, '/content/train2014/COCO_train2014_000000178244.jpg'), (0.009483212149499431, '/content/train2014/COCO_train2014_000000526565.jpg'), (0.010467106274626714, '/content/train2014/COCO_train2014_000000073104.jpg'), (0.010501688060765568, '/content/train2014/COCO_train2014_000000193707.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000474775.jpg
# SCORE IS ....
# 0.00864110449319555
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000178244.jpg
# SCORE IS ....
# 0.009258090841805178
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000178244.jpg
# SCORE IS ....
# 0.009258090841805178
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000526565.jpg
# SCORE IS ....
# 0.009483212149499431
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000073104.jpg
# SCORE IS ....
# 0.010467106274626714
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000193707.jpg
# SCORE IS ....
# 0.010501688060765568

# %%
caption="a white woman with a laptop and projector"
get_top_k_images(6,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.0023912239181387296, '/content/train2014/COCO_train2014_000000296170.jpg'), (0.002772689891427982, '/content/train2014/COCO_train2014_000000002693.jpg'), (0.002834466787858203, '/content/train2014/COCO_train2014_000000016468.jpg'), (0.0029498631531166414, '/content/train2014/COCO_train2014_000000547827.jpg'), (0.003346875886395831, '/content/train2014/COCO_train2014_000000547764.jpg'), (0.003401009579123093, '/content/train2014/COCO_train2014_000000108589.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000296170.jpg
# SCORE IS ....
# 0.0023912239181387296
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000002693.jpg
# SCORE IS ....
# 0.002772689891427982
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000016468.jpg
# SCORE IS ....
# 0.002834466787858203
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000547827.jpg
# SCORE IS ....
# 0.0029498631531166414
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000547764.jpg
# SCORE IS ....
# 0.003346875886395831
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000108589.jpg
# SCORE IS ....
# 0.003401009579123093

# %%
caption =  "man snowboarding on a white snowy mountain"
get_top_k_images(5,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.007654403596692172, '/content/train2014/COCO_train2014_000000241762.jpg'), (0.008521644403462147, '/content/train2014/COCO_train2014_000000459943.jpg'), (0.008534172168314313, '/content/train2014/COCO_train2014_000000096622.jpg'), (0.008635520368800664, '/content/train2014/COCO_train2014_000000440675.jpg'), (0.008752784021518245, '/content/train2014/COCO_train2014_000000458908.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000241762.jpg
# SCORE IS ....
# 0.007654403596692172
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000459943.jpg
# SCORE IS ....
# 0.008521644403462147
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000096622.jpg
# SCORE IS ....
# 0.008534172168314313
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000440675.jpg
# SCORE IS ....
# 0.008635520368800664
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000458908.jpg
# SCORE IS ....
# 0.008752784021518245

# %%
caption = "man swinging a tennis racquet and hitting a ball"
get_top_k_images(4,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.008280360997368286, '/content/train2014/COCO_train2014_000000020012.jpg'), (0.008663764174876798, '/content/train2014/COCO_train2014_000000166630.jpg'), (0.008782982481108148, '/content/train2014/COCO_train2014_000000105228.jpg'), (0.00891780016067717, '/content/train2014/COCO_train2014_000000012795.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000020012.jpg
# SCORE IS ....
# 0.008280360997368286
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000166630.jpg
# SCORE IS ....
# 0.008663764174876798
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000105228.jpg
# SCORE IS ....
# 0.008782982481108148
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000012795.jpg
# SCORE IS ....
# 0.00891780016067717

# %%
caption = "man sitting on a motorbike"
get_top_k_images(3,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.006280282691913053, '/content/train2014/COCO_train2014_000000505579.jpg'), (0.007199311073671721, '/content/train2014/COCO_train2014_000000515701.jpg'), (0.00782310985019663, '/content/train2014/COCO_train2014_000000065420.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000505579.jpg
# SCORE IS ....
# 0.006280282691913053
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000515701.jpg
# SCORE IS ....
# 0.007199311073671721
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000065420.jpg
# SCORE IS ....
# 0.00782310985019663

# %%
caption = "a bathroom area decorated in all white with lights above the mirror"
get_top_k_images(6,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.010711809149688334, '/content/train2014/COCO_train2014_000000042384.jpg'), (0.011604102969048569, '/content/train2014/COCO_train2014_000000560748.jpg'), (0.011906326481985696, '/content/train2014/COCO_train2014_000000093581.jpg'), (0.013361311323145664, '/content/train2014/COCO_train2014_000000272492.jpg'), (0.01343682105784666, '/content/train2014/COCO_train2014_000000091543.jpg'), (0.013711886616541769, '/content/train2014/COCO_train2014_000000360555.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000042384.jpg
# SCORE IS ....
# 0.010711809149688334
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000560748.jpg
# SCORE IS ....
# 0.011604102969048569
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000093581.jpg
# SCORE IS ....
# 0.011906326481985696
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000272492.jpg
# SCORE IS ....
# 0.013361311323145664
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000091543.jpg
# SCORE IS ....
# 0.01343682105784666
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000360555.jpg
# SCORE IS ....
# 0.013711886616541769

# %%
caption = "a brown cat walking"
get_top_k_images(5,caption)
# Out:
# cap_emb is  (1, 1024)
# imgs_embs are (3200, 1024)
# the sorted order is  [(0.00840406354053963, '/content/train2014/COCO_train2014_000000403398.jpg'), (0.008606338388254864, '/content/train2014/COCO_train2014_000000490935.jpg'), (0.009546738581916403, '/content/train2014/COCO_train2014_000000414546.jpg'), (0.009741818317595075, '/content/train2014/COCO_train2014_000000425381.jpg'), (0.010061183890069936, '/content/train2014/COCO_train2014_000000553509.jpg')]
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000403398.jpg
# SCORE IS ....
# 0.00840406354053963
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000490935.jpg
# SCORE IS ....
# 0.008606338388254864
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000414546.jpg
# SCORE IS ....
# 0.009546738581916403
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000425381.jpg
# SCORE IS ....
# 0.009741818317595075
# ----------------------------------------------------------------------------------------------------
# IMAGE IS ... /content/train2014/COCO_train2014_000000553509.jpg
# SCORE IS ....
# 0.010061183890069936
